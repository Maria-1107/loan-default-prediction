# %%
# Import Necessary Lib
import pandas as pd
import numpy as np  
from sklearn.preprocessing import LabelEncoder

# %%
# import dataset
loan_data=pd.read_csv("Loan_default.csv")
loan_data
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96   56   85994       50587          520              80
# 1       HPSK72WA7R   69   50432      124440          458              15
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 3       V2KKSFM3UN   32   31713       44799          743               0
# 4       EY08JDHTZP   60   20437        9139          633               8
# ...            ...  ...     ...         ...          ...             ...
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Initial analysis

# %%
loan_data.isna().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %%
loan_data.shape
# Out:
# (255347, 18)

# %%
loan_data.dtypes
# Out:
# LoanID                str
# Age                 int64
# Income              int64
# LoanAmount          int64
# CreditScore         int64
# MonthsEmployed      int64
# NumCreditLines      int64
# InterestRate      float64
# LoanTerm            int64
# DTIRatio          float64
# Education             str
# EmploymentType        str
# MaritalStatus         str
# HasMortgage           str
# HasDependents         str
# LoanPurpose           str
# HasCoSigner           str
# Default             int64
# dtype: object

# %%
loan_data.describe(include="all")
# Out:
#             LoanID            Age         Income     LoanAmount  \
# count       255347  255347.000000  255347.000000  255347.000000
# unique      255347            NaN            NaN            NaN
# top     I38PQUQS96            NaN            NaN            NaN
# freq             1            NaN            NaN            NaN
# mean           NaN      43.498306   82499.304597  127578.865512
# std            NaN      14.990258   38963.013729   70840.706142
# min            NaN      18.000000   15000.000000    5000.000000
# 25%            NaN      31.000000   48825.500000   66156.000000
# 50%            NaN      43.000000   82466.000000  127556.000000
# 75%            NaN      56.000000  116219.000000  188985.000000
# max            NaN      69.000000  149999.000000  249999.000000
#
#           CreditScore  MonthsEmployed  NumCreditLines   InterestRate  \
# count   255347.000000   255347.000000   255347.000000  255347.000000
# ...

# %% [markdown]
# # Data preparation
# ## Data Cleaning

# %%
loan_data.drop(labels="LoanID",axis=1,inplace=True)

# %%
loan_data.head(10)
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
# 5   25   90298       90448          720              18               2
# 6   38  111188      177025          429              80               1
# 7   56  126802      155511          531              67               4
# 8   36   42053       92357          827              83               1
# 9   40  132784      228510          480             114               4
#
#    InterestRate  LoanTerm  DTIRatio    Education EmploymentType MaritalStatus  \
# 0         15.23        36      0.44   Bachelor's      Full-time      Divorced
# ...

# %% [markdown]
# ## Data Transformation
# #### If data is continous: Standard Scaler, MinMaxScaler, Robust Scaler
# #### If data is discrete: Label encoder, One hot Encoder

# %% [markdown]
# ### One hot encoder
# ##### This can be achieved by using any of the following 2 lib:
# ##### Pandas-pd.get_dummies()
# #####    skLearn- OneHotEncoder()

# %%
# take a cope of cleaned data
Loan_data_copy=loan_data.copy()
Loan_data_copy
# Out:
#         Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0        56   85994       50587          520              80               4
# 1        69   50432      124440          458              15               1
# 2        46   84208      129188          451              26               3
# 3        32   31713       44799          743               0               3
# 4        60   20437        9139          633               8               4
# ...     ...     ...         ...          ...             ...             ...
# 255342   19   37979      210682          541             109               4
# 255343   32   51953      189899          511              14               2
# 255344   56   84820      208294          597              70               3
# 255345   42   85109       60575          809              40               1
# 255346   62   22418       18481          636             113               2
#
# ...

# %%
columns = [
    "Education",
    "EmploymentType",
    "MaritalStatus",
    "HasMortgage",
    "HasDependents",
    "LoanPurpose",
    "HasCoSigner"
]

unique_values_df = pd.DataFrame({
    col: pd.Series(loan_data[col].unique())
    for col in columns
})

unique_values_df
# Out:
#      Education EmploymentType MaritalStatus HasMortgage HasDependents  \
# 0   Bachelor's      Full-time      Divorced         Yes           Yes
# 1     Master's     Unemployed       Married          No            No
# 2  High School  Self-employed        Single         NaN           NaN
# 3          PhD      Part-time           NaN         NaN           NaN
# 4          NaN            NaN           NaN         NaN           NaN
#
#   LoanPurpose HasCoSigner
# 0       Other         Yes
# 1        Auto          No
# 2    Business         NaN
# 3        Home         NaN
# 4   Education         NaN

# %%
columns=[
    "Education",
    "EmploymentType",
    "MaritalStatus",
    "HasMortgage",
    "HasDependents",
    "LoanPurpose",
    "HasCoSigner"
]

mappings={}
for col in columns:
    le_encoder=LabelEncoder()
    Loan_data_copy[col]=le_encoder.fit_transform(Loan_data_copy[col])
    mappings[col]=dict(zip(le_encoder.classes_,le_encoder.transform(le_encoder.classes_)))

for col, mapping in mappings.items():
    print(f"\n{col}:")
    print(mapping)
# Out:
# Education:
# {"Bachelor's": np.int64(0), 'High School': np.int64(1), "Master's": np.int64(2), 'PhD': np.int64(3)}
#
# EmploymentType:
# {'Full-time': np.int64(0), 'Part-time': np.int64(1), 'Self-employed': np.int64(2), 'Unemployed': np.int64(3)}
#
# MaritalStatus:
# {'Divorced': np.int64(0), 'Married': np.int64(1), 'Single': np.int64(2)}
#
# HasMortgage:
# {'No': np.int64(0), 'Yes': np.int64(1)}
#
# HasDependents:
# {'No': np.int64(0), 'Yes': np.int64(1)}
#
# LoanPurpose:
# {'Auto': np.int64(0), 'Business': np.int64(1), 'Education': np.int64(2), 'Home': np.int64(3), 'Other': np.int64(4)}
#
# HasCoSigner:
# {'No': np.int64(0), 'Yes': np.int64(1)}

# %%
Loan_data_copy.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Education  EmploymentType  MaritalStatus  \
# 0         15.23        36      0.44          0               0              0
# 1          4.81        60      0.68          2               0              1
# 2         21.17        24      0.31          2               3              0
# 3          7.07        24      0.23          1               0              1
# 4          6.51        48      0.73          0               3              0
#
# ...

# %%
# Hint: use value_counts() on the Default column
# Then plot it using matplotlib or seaborn
loan_data["Default"].value_counts()
# Out:
# Default
# 0    225694
# 1     29653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Hint: use sns.countplot()
sns.countplot(x="Default", data=loan_data)
plt.title("Default vs Non-Default")
plt.show()

# %%
# Does credit score affect default?
sns.histplot(data=loan_data, x="CreditScore", hue="Default")
plt.title("Credit Score Distribution by Default")
plt.show()

# %%
sns.boxplot(x="Default", y="Income", data=loan_data)
plt.title("Income vs Default")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(Loan_data_copy.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
Loan_data_copy.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Education  EmploymentType  MaritalStatus  \
# 0         15.23        36      0.44          0               0              0
# 1          4.81        60      0.68          2               0              1
# 2         21.17        24      0.31          2               3              0
# 3          7.07        24      0.23          1               0              1
# 4          6.51        48      0.73          0               3              0
#
# ...

# %%
# Input data
X=Loan_data_copy.drop(labels="Default",axis=1)
# Output Data
Y=Loan_data_copy["Default"]

print(X.shape)
print(Y.shape)
# Out:
# (255347, 16)
# (255347,)

# %%
# Model Building
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,shuffle=True,random_state=76)

# %%
X_train
# Out:
#         Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 39666    66   62010       10017          389              34               4
# 122408   48   54315       55723          438             104               4
# 242974   60   19858      145538          300              48               1
# 195396   50   96911       49803          561              89               4
# 199840   34   75693       48261          457              27               4
# ...     ...     ...         ...          ...             ...             ...
# 153882   33  142654      134416          481             111               1
# 170368   48  119691      153613          790             112               1
# 75143    26  120650       43098          838              97               4
# 208887   38  108935       40253          417              88               4
# 166561   56   45903      193224          814              25               3
#
# ...

# %%
# Model Training
decision_tree=DecisionTreeClassifier(class_weight='balanced')
random_forest=RandomForestClassifier(class_weight='balanced')
logistic_model=LogisticRegression(class_weight='balanced')

# %%
decision_tree
# Out:
# DecisionTreeClassifier(class_weight='balanced')

# %%
random_forest
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
logistic_model
# Out:
# LogisticRegression(class_weight='balanced')

# %%
logistic_model.fit(X_train,Y_train)
# Out:
# c:\Users\REXCY\anaconda3\envs\loan-default\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced')

# %%
decision_tree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced')

# %%
random_forest.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
# Model testing
# Training data(logistic_model)

y_logistic_train=logistic_model.predict(X_train)
y_logistic_train
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(204277,))

# %%
# Model testing
# Training data(decision_tree)

y_decision_train=decision_tree.predict(X_train)
y_decision_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(204277,))

# %%
# Model testing
# Training data(Random_forest)

y_random_train=random_forest.predict(X_train)
y_random_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(204277,))

# %%
# Model testing
# Testing data(Logistic_model)

y_logistic_test=logistic_model.predict(X_test)
y_logistic_test
# Out:
# array([0, 0, 0, ..., 0, 1, 0], shape=(51070,))

# %%
# Model testing
# Testing data(decision_tree)

y_decision_test=decision_tree.predict(X_test)
y_decision_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(51070,))

# %%
# Model testing
# Testing data(Random_forest)

y_random_test=random_forest.predict(X_test)
y_random_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(51070,))

# %%
# Model evaluation

from sklearn.metrics import accuracy_score

# %%
# training accuracy(logistic_model)
accuracy_score(Y_train,y_logistic_train)
# Out:
# 0.6658703623021681

# %%
# training accuracy(decision_tree)
accuracy_score(Y_train,y_decision_train)
# Out:
# 1.0

# %%
# training accuracy(random_forest)
accuracy_score(Y_train,y_random_train)
# Out:
# 0.9998776171570956

# %%
# test accuracy(logistic_model)
accuracy_score(Y_test,y_logistic_test)
# Out:
# 0.6667123555903661

# %%
# test accuracy(decision_tree)
accuracy_score(Y_test,y_decision_test)
# Out:
# 0.8157626786763266

# %%
# test accuracy(random_forest)
accuracy_score(Y_test,y_random_test)
# Out:
# 0.8757783434501665

# %%
from sklearn.metrics import confusion_matrix,recall_score,classification_report

#Logistic_model
print("Logistic Regression")
print(confusion_matrix(Y_test,y_logistic_test))
print("Recall:", recall_score(Y_test,y_logistic_test))
print(classification_report(Y_test,y_logistic_test))

# Decision Tree
print("Decision Tree")
print(confusion_matrix(Y_test, y_decision_test))
print("Recall:", recall_score(Y_test, y_decision_test))
print(classification_report(Y_test, y_decision_test))

# Random Forest
print("Random Forest")
print(confusion_matrix(Y_test, y_random_test))
print("Recall:", recall_score(Y_test, y_random_test))
print(classification_report(Y_test, y_random_test))
# Out:
# Logistic Regression
# [[30032 15013]
#  [ 2008  4017]]
# Recall: 0.6667219917012448
#               precision    recall  f1-score   support
#
#            0       0.94      0.67      0.78     45045
#            1       0.21      0.67      0.32      6025
#
#     accuracy                           0.67     51070
#    macro avg       0.57      0.67      0.55     51070
# weighted avg       0.85      0.67      0.73     51070
#
# Decision Tree
# [[40456  4589]
#  [ 4820  1205]]
# Recall: 0.2
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90     45045
#            1       0.21      0.20      0.20      6025
#
#     accuracy                           0.82     51070
#    macro avg       0.55      0.55      0.55     51070
# weighted avg       0.81      0.82      0.81     51070
#
# Random Forest
# [[43725  1320]
#  [ 5024  1001]]
# Recall: 0.16614107883817428
#               precision    recall  f1-score   support
#
# ...
